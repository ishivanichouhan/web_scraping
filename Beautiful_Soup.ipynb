# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
from bs4 import  BeautifulSoup
import requests
reviews = []
for j in range(2,200):

    url = "https://magicpin.in/Bhopal/Hoshangabad-Road/Restaurant/Vrindavan-Dhaba/store/20bc99/reviews?page={}".format(j)
    data = requests.get(url)
    soup = BeautifulSoup(data.text, "html.parser")
    for i in soup.find_all("p", class_ = "review"):
      reviews.append(i.text.strip())

# %%
len(reviews)
# Out:
# 1365

# %%
reviews
# Out:
# ['Loved the quality of service at this place',
#  "Didn't like the quality of service at this place",
#  'Loved the ambience at this place',
#  'Loved the quality of service at this place',
#  "Didn't like the quality of service, ambience, safety measures & cleanliness, taste, and price, promotions, & discounts at this place",
#  'Loved the quality of service, taste, and price, promotions, & discounts at this place',
#  'Loved the food, service and crowd at this place',
#  'Loved the service at this place',
#  'Loved the food, service, ambience, music, drinks and crowd at this place',
#  'Loved the food, ambience, service, music, crowd and drinks at this place',
#  'Loved the food, service and crowd at this place',
#  'Loved the service at this place',
#  'Loved the food, service and crowd at this place',
#  'Loved the ambience, service and food at this place',
#  "Didn't like the price, promotions, & discounts at this place",
# ...

# %%
df = DataFrame(reviews)

# %%
from bs4 import  BeautifulSoup
import requests
reviews = []
for j in range(2,200):

    Url = "https://magicpin.in/Bhopal/Jhangirabad/Restaurant/Hotel-Taj/store/20c411/reviews?page={}".format(j)
    data = requests.get(Url)
    soup = BeautifulSoup(data.text, "html.parser")
    for i in soup.find_all("p", class_ = "review"):
      reviews.append(i.text.strip())

# %%
len(reviews)
# Out:
# 396

# %%
reviews
# Out:
# ['Loved the food and service at this place',
#  'Loved the food and service at this place',
#  'Loved the food and service at this place',
#  'Loved the food and service at this place',
#  'Loved the food and service at this place',
#  'Loved the food and service at this place',
#  'Loved the food and service at this place',
#  'Loved the food and service at this place',
#  'Loved the food and service at this place',
#  'Loved the food and service at this place',
#  'Loved the food and service at this place',
#  'Loved the food and service at this place',
#  'Loved the food and service at this place',
#  'Loved the food and service at this place',
#  'Loved the food and service at this place',
#  'Loved the food and service at this place',
#  'Loved the food and service at this place',
#  'Loved the food and service at this place',
#  'Loved the food and service at this place',
#  'Loved the food and service at this place',
#  'Loved the food and service at this place',
# ...

# %%
df = pd.DataFrame(reviews)
df
# Out:
#                                             0
# 0    Loved the food and service at this place
# 1    Loved the food and service at this place
# 2    Loved the food and service at this place
# 3    Loved the food and service at this place
# 4    Loved the food and service at this place
# ..                                        ...
# 391  Loved the food and service at this place
# 392  Loved the food and service at this place
# 393  Loved the food and service at this place
# 394  Loved the food and service at this place
# 395  Loved the food and service at this place
#
# [396 rows x 1 columns]
